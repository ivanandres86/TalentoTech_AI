# %% [markdown]
# # **Instalar NLTK**

# %%
# !pip install nltk

# %% [markdown]
#  Download NLTK DATOS

# %%
from nltk.tokenize import word_tokenize
nltk.download('punkt')

sentence = "NLTK es una bblioteca de procesamiento de lenguaje natural"
tokens = word_tokenize(sentence)
print(tokens)
# Out:
# ['NLTK', 'es', 'una', 'bblioteca', 'de', 'procesamiento', 'de', 'lenguaje', 'natural']
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
